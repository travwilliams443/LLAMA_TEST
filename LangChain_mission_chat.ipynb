# %%
from langchain.document_loaders import UnstructuredURLLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter, HTMLHeaderTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma

# %%
# List of URLs to scrape
urls = [
    "https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island",
    "https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District",
    "https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport",
    "https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters",
    "https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters",
    "https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong"
]

# %%
headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
]

# %%
html_splitter = HTMLHeaderTextSplitter(
    headers_to_split_on,
    return_each_element=False,
)

# %%
docs = []

for u in urls:
    splits = html_splitter.split_text_from_url(u)
    for split in splits:
        split.metadata['url'] = u
    docs.extend(splits)

# %%
for doc in docs:
    if doc.metadata:
        print(doc.metadata, "\n")
# Out:
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': '1st Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': '1st Mission', 'Header 3': 'Location', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': '1st Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': '1st Mission', 'Header 3': 'Next', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': '1st Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': '1st Mission', 'Header 3': 'Previous', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Name in Official Guide', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Number in Game Data', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Augmentation canisters[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Weapon modifications[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Maps[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Brief walkthrough[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Detailed walkthrough[]', 'Header 3': 'South Dock[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Detailed walkthrough[]', 'Header 3': 'UNATCO Headquarters exterior[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Detailed walkthrough[]', 'Header 3': 'Storage bunker[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Detailed walkthrough[]', 'Header 3': 'North dock[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Detailed walkthrough[]', 'Header 3': 'Entering the Statue of Liberty compound[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Detailed walkthrough[]', 'Header 3': 'Inside the Statue[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Detailed walkthrough[]', 'Header 3': 'UNATCO HQ[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Detailed walkthrough[]', 'Header 3': 'Notes[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': 'Fan Feed', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 2': '', 'Header 3': 'Explore properties', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 3': 'Overview', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 3': 'Community', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'Header 3': 'Advertise', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_1st_Mission:_Liberty_Island'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': '2nd Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': '2nd Mission', 'Header 3': 'Location', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': '2nd Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': '2nd Mission', 'Header 3': 'Next', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': '2nd Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': '2nd Mission', 'Header 3': 'Previous', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Name in Official Guide', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Number in Game Data', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Summary[]', 'Header 3': 'Map segments[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Augmentation canisters[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Weapon modifications[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': '\xa0Maps[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Battery Park[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': "Hell's Kitchen[]", 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Warehouse District[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Trivia[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'References[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': 'Fan Feed', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 2': '', 'Header 3': 'Explore properties', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 3': 'Overview', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 3': 'Community', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'Header 3': 'Advertise', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': '3rd Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': '3rd Mission', 'Header 3': 'Location', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': '3rd Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': '3rd Mission', 'Header 3': 'Next', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': '3rd Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': '3rd Mission', 'Header 3': 'Previous', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Name in Official Guide', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Number in Game Data', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Augmentation canisters[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Weapon modifications[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': '\xa0Maps[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'UNATCO Headquarters (second visit)[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Battery Park (second visit)[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Brooklyn Bridge Station[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Mole Tunnels[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Helibase[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Airfield[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Hangar and 747[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Notes[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': 'Fan Feed', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 2': '', 'Header 3': 'Explore properties', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 3': 'Overview', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 3': 'Community', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'Header 3': 'Advertise', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_3rd_Mission:_Brooklyn_Bridge_Station,_Mole_Tunnels,_and_LaGuardia_Airport'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': '4th Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': '4th Mission', 'Header 3': 'Location', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': '4th Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': '4th Mission', 'Header 3': 'Next', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': '4th Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': '4th Mission', 'Header 3': 'Previous', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Name in Official Guide', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Number in Game Data', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Summary[]', 'Header 3': 'Goals[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Summary[]', 'Header 3': 'Skill Points[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Summary[]', 'Header 3': 'Map segments[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Augmentation canisters[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Weapon modifications[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'UNATCO Headquarters (third visit)[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': "Hell's Kitchen (second visit)[]", 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'NSF Headquarters[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Return to Paul and escape to Battery Park[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Notes[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Bugs[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Trivia[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': 'Fan Feed', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 2': '', 'Header 3': 'Explore properties', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 3': 'Overview', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 3': 'Community', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'Header 3': 'Advertise', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_4th_Mission:_Hell%27s_Kitchen_(Second_Visit)_and_NSF_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': '5th Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': '5th Mission', 'Header 3': 'Location', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': '5th Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': '5th Mission', 'Header 3': 'Next', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': '5th Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': '5th Mission', 'Header 3': 'Previous', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Name in Official Guide', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Number in Game Data', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Summary[]', 'Header 3': 'Map segments[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Augmentation canisters[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Weapon modifications[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Maps[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Detention[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Armory and Robot Maintenance[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Nanotech and Medical Labs[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'UNATCO Headquarters (fourth visit)[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Notes[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': 'Fan Feed', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 2': '', 'Header 3': 'Explore properties', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 3': 'Overview', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 3': 'Community', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'Header 3': 'Advertise', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_5th_Mission:_Secret_MJ12_Facility_and_UNATCO_Headquarters'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': '6th Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': '6th Mission', 'Header 3': 'Location', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': '6th Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': '6th Mission', 'Header 3': 'Next', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': '6th Mission', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': '6th Mission', 'Header 3': 'Previous', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Name in Official Guide', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Additional Information', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Additional Information', 'Header 3': 'Mission Number in Game Data', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Summary[]', 'Header 3': 'Map segments[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Augmentation Canisters[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Collectibles[]', 'Header 3': 'Weapon Modifications[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Maps[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'MJ12 Helibase[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Wan Chai District - Overview[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'Investigating Maggie Chow[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'VersaLife Facility - Part 1[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Walkthrough[]', 'Header 3': 'VersaLife Facility - Part 2[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Notes[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'References[]', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': 'Fan Feed', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 2': '', 'Header 3': 'Explore properties', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 3': 'Overview', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 3': 'Community', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'Header 3': 'Advertise', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}
#
# {'url': 'https://deusex.fandom.com/wiki/Deus_Ex_6th_Mission:_Hong_Kong'}

# %%
# Create embeddings and store in vector database
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
vectorstore = Chroma.from_documents(docs, embeddings)

# %%
# Function to query the database
def query_database(query: str, k: int = 1):
    matching_docs = vectorstore.similarity_search(query, k=k)
    return matching_docs if matching_docs else []

# %%
# Example usage
query_database("When do I talk to my brother on liberty island?", 3)
# Out:
# [Document(metadata={'Header 2': '2nd Mission', 'Header 3': 'Previous'}, page_content='1st Mission: Liberty Island'),
#  Document(metadata={'Header 2': '2nd Mission', 'Header 3': 'Previous', 'url': 'https://deusex.fandom.com/wiki/Deus_Ex_2nd_Mission:_Battery_Park,_Hell%27s_Kitchen,_and_Warehouse_District'}, page_content='1st Mission: Liberty Island'),
#  Document(metadata={'Header 2': 'Detailed walkthrough[]', 'Header 3': 'South Dock[]'}, page_content='You begin on the south pier of Liberty Island, equipped only with a Pistol, a Riot Prod, and a Medkit. Alex Jacobson messages you through your infolink and tells you that your brother, Paul Denton, is on his way to meet you on the pier. Move forward and you\'ll see a figure in a trench coat heading towards your direction. This is Paul, and a conversation will trigger as soon as he\'s near you.  \nPaul tells you that the NSF terrorist group has taken over the statue and has taken Gunther Hermann, one of UNATCO\'s top agents, hostage. Paul offers you to choose one additional weapon for the mission: a sniper rifle, a GEP gun, or a mini-crossbow. Each weapon suits very different tactics. However, the GEP gun is the only weapon that is not otherwise obtainable on this mission. A sniper rifle can be found on an NSF member near the front entrance. NSF members will also carry mini-crossbows.  \nOnce you\'re armed, Paul informs you that your primary objective is to locate and interrogate the NSF commander, who is probably at the makeshift command center at the top of the statue. Now, look for a crowbar among a stack of crates on the right-hand side of the pier and pick it up. Use it to smash the two nearby wooden crates, in which you\'ll find a pair of binoculars and a lockpick.  \nGo down the staircase on the left into the water to find a broken shark cage. Inside the shark cage are two other wooden crates. Smash them both to find a multitool and a bioelectric cell, and climb back out. You can talk to Corporal Collins, who gives you more information on Gunther. You can also talk to Paul two more times to uncover additional information. Keep heading down the dock to find some more wooden crates in the corner. Destroy all of them in order to find 10mm Ammo, a Prod Charger, and some Darts.  \nAfterwards, proceed up the ramp and take a look around.\xa0There is a\xa0baton\xa0that\'s on the body of a UNATCO soldier at your feet.\xa0Alex will transmit to you a map of the island, so take a look at this to plan your approach. Two guards patrol this area, so either avoid them or get their attention so they will chase you down onto the docks to be eliminated by a friendly Security Bot. These two guards will carry 10mm Ammo and a Combat Knife, which is standard for most of the NSF enemies.  \nOnce both guards are down, head left after the ramp and look for a small metal crate in a storage area. This storage area is to the immediate northwest of the ramp from the south dock. Take the crate and place it next to the large stack of crates left of the path. Jump on top and smash the wooden crate to find a gas grenade. At the storage area, there\'s an locked panel labeled "U.N.A.T.C.O. Medlab" that houses three medbots. The panel is locked, but using a lockpick here is unnecessary. The panel can instead be opened using any one of crates of TNT to the east of the area. Pick up a TNT crate, and either throw it at the panel up close, or position the TNT crate near the panel and shoot it with your pistol. The unlocked medbots can be used to restore your health whenever you\'re injured. Keep going down the main path - there are two guards ahead, you can either kill them now or sneak past them to deal with them later. Turn left to arrive at the exterior of the UNATCO HQ.')]

# %%
from openai import OpenAI

client = OpenAI()

# %%
def create_prompt(retrieved_content, user_question):
    prompt = f"Context:\n{retrieved_content}\n\nQuestion: {user_question}\n\nAnswer:"
    print("Retrieved content: ", retrieved_content, "-------------- \n\n")
    return prompt

# %%
def chat_with_gpt(prompt):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are an assistant helping with questions about a specific mission. Use the provided context to answer questions. Provide detailed instructions to guide the player."},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

# %%
def mission_qa(user_question):
    # Perform similarity search
    relevant_docs = query_database(user_question, k=2)  # Adjust k as needed
    
    # Construct context from relevant documents
    context = "\n".join([doc.page_content for doc in relevant_docs])
    
    # Create prompt and get response
    prompt = create_prompt(context, user_question)
    response = chat_with_gpt(prompt)
    
    return response

# %%
# Example usage
question = "After I escape the jail cell in UNATCO HQ, how do I get to the robot maintenance area?"
answer = mission_qa(question)
print("Response: ", answer)
# Out:
# Retrieved content:  The compound can be entered through either the front entrance or the rear entrance.
# Going in the front way, though straightforward, has its hazards. A wheeled Security Bot patrols the area immediately in front of the statue, and there are also three or four terrorists nearby, one of which is especially dangerous as he is armed with a sniper rifle.
# Exit the northern docks and head East, following the same path you took before. If you took the GEP Gun at the beginning, use it to destroy the bot from a distance (hold the crosshair over the target until the weapon beeps continuously, signaling that it is locked on, and then fire). Preferably, engage the bot when it is patrolling on the south side of its route to minimize the chance that the nearby terrorists will hear the explosion. Once the bot is taken care of, either neutralize the remaining terrorists or simply avoid them. There is a room in the center of this area with a locked chest containing ammo and a credit chit. If you go back to the right of the dock you started from and pick up one of the crates of TNT then you can throw it at the bot as it passes in front of the room with the chest. This will destroy the bot and open the chest. It will also damage your legs and draw the attention of any remaining enemies so some care is needed. If you are being chased, you can run back to UNATCO HQ or the dock to get some assistance killing the enemies. Then, you can go to the medbot to heal if necessary.
# Head for the front doors. They're locked and the camera will set off the alarm if you stand in front of it, so stay out of its line of sight and move up to the security computer to the left of the doors. Log into it with the login and password you found in the datacube (NSF001/smashthestate) and turn off the camera and unlock the doors. Smash the crate nearby for a Lockpick and enter the lobby.  If you draw attention, run out again and the turret will attack anyone who follows you.
# Climb back onto the dock and make your way back to the storage facility and the huge piles of crates and containers nearby. Climb the containers, using the ladders and small metal crates, and climb over the wall onto the outside of the statue complex. There are two guards patrolling to the south, you can engage them if you like but it's easier to avoid them. From here, go west until you run into another guard. Dispatch him, but watch out. There are two around the corner. You may want to lure them around the corner and then shoot the box of TNT as they pass it, but this is difficult to do reliably unless you invested most of your skills in pistol marksmanship. Once they're out of the way follow the two ramps up to the tower. Watch out, three of the four passages here are booby-trapped with gas grenades. Move in quickly and right click on them to defuse them before they go off - just like in training. Once that's done, quietly move into the center and listen as the two thugs nearby talk about "the shipment." You can dispatch them if you wish, but as long as you keep crouched and stay behind them you can just ignore them. Head downstairs, ignore the patrolling guard, and continue downwards in to the lobby. Behind the corner on the right is a security camera and a crate containing a lockpick. You can either disable the camera or evade it if you are quick enough. Take note of the gun turret on the roof, which will activate if an alarm is tripped.
# The compound can be entered through either the front entrance or the rear entrance.
# Going in the front way, though straightforward, has its hazards. A wheeled Security Bot patrols the area immediately in front of the statue, and there are also three or four terrorists nearby, one of which is especially dangerous as he is armed with a sniper rifle.
# Exit the northern docks and head East, following the same path you took before. If you took the GEP Gun at the beginning, use it to destroy the bot from a distance (hold the crosshair over the target until the weapon beeps continuously, signaling that it is locked on, and then fire). Preferably, engage the bot when it is patrolling on the south side of its route to minimize the chance that the nearby terrorists will hear the explosion. Once the bot is taken care of, either neutralize the remaining terrorists or simply avoid them. There is a room in the center of this area with a locked chest containing ammo and a credit chit. If you go back to the right of the dock you started from and pick up one of the crates of TNT then you can throw it at the bot as it passes in front of the room with the chest. This will destroy the bot and open the chest. It will also damage your legs and draw the attention of any remaining enemies so some care is needed. If you are being chased, you can run back to UNATCO HQ or the dock to get some assistance killing the enemies. Then, you can go to the medbot to heal if necessary.
# Head for the front doors. They're locked and the camera will set off the alarm if you stand in front of it, so stay out of its line of sight and move up to the security computer to the left of the doors. Log into it with the login and password you found in the datacube (NSF001/smashthestate) and turn off the camera and unlock the doors. Smash the crate nearby for a Lockpick and enter the lobby.  If you draw attention, run out again and the turret will attack anyone who follows you.
# Climb back onto the dock and make your way back to the storage facility and the huge piles of crates and containers nearby. Climb the containers, using the ladders and small metal crates, and climb over the wall onto the outside of the statue complex. There are two guards patrolling to the south, you can engage them if you like but it's easier to avoid them. From here, go west until you run into another guard. Dispatch him, but watch out. There are two around the corner. You may want to lure them around the corner and then shoot the box of TNT as they pass it, but this is difficult to do reliably unless you invested most of your skills in pistol marksmanship. Once they're out of the way follow the two ramps up to the tower. Watch out, three of the four passages here are booby-trapped with gas grenades. Move in quickly and right click on them to defuse them before they go off - just like in training. Once that's done, quietly move into the center and listen as the two thugs nearby talk about "the shipment." You can dispatch them if you wish, but as long as you keep crouched and stay behind them you can just ignore them. Head downstairs, ignore the patrolling guard, and continue downwards in to the lobby. Behind the corner on the right is a security camera and a crate containing a lockpick. You can either disable the camera or evade it if you are quick enough. Take note of the gun turret on the roof, which will activate if an alarm is tripped. --------------
#
#
# Response:  To reach the robot maintenance area after escaping the jail cell in UNATCO HQ, follow these steps:
#
# 1. **Exit Your Cell**: After freeing yourself from your jail cell, look for the exit to the hallway. Move cautiously, as there could be guards or security measures.
#
# 2. **Navigate the Hallways**: Once you are in the main area of UNATCO HQ:
#    - Avoid confrontation if possible. Stick to the shadows and use stealth to evade detection.
#    - Make your way through the main lobby. Look for doors that lead further into the facility.
#
# 3. **Locate the Security Computer**: You will need to access the security systems. Look for a security computer; typically, it will be near entrances or other critical access points. Make sure to check your surroundings for guards or cameras.
#
# 4. **Disable Security Systems**: If there's a camera in view, use a lockpick or hack into the security computer to disable any alarms or cameras that might hinder your progress to the robot maintenance area.
#
# 5. **Proceed to the Robot Maintenance Area**:
#    - Look for a marked door or passage leading to the maintenance area. The robot maintenance area should be well-signposted and secured.
#    - If you encounter locked doors, try to use your lockpicks or any access codes you may have discovered during your previous missions or encounters.
#
# 6. **Avoid Confrontation**: If you are detected or chased by guards while moving towards the maintenance area, use the environment to your advantage. Hide behind walls or crates, and consider using diversion tactics if necessary.
#
# 7. **Entering the Robot Maintenance Area**: Once you reach the entrance to the robot maintenance area, ensure that the area is clear before making your way inside.
#
# By keeping these steps in mind, you should successfully navigate through UNATCO HQ and reach the robot maintenance area without too much difficulty. Good luck!
